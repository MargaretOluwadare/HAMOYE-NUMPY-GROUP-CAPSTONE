# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
perf_df = pd.read_csv("data/trainperf.csv")
perf_df.head()
# Out:
#                          customerid  systemloanid  loannumber  \
# 0  8a2a81a74ce8c05d014cfb32a0da1049     301994762          12
# 1  8a85886e54beabf90154c0a29ae757c0     301965204           2
# 2  8a8588f35438fe12015444567666018e     301966580           7
# 3  8a85890754145ace015429211b513e16     301999343           3
# 4  8a858970548359cc0154883481981866     301962360           9
#
#                  approveddate                creationdate  loanamount  \
# 0  2017-07-25 08:22:56.000000  2017-07-25 07:22:47.000000     30000.0
# 1  2017-07-05 17:04:41.000000  2017-07-05 16:04:18.000000     15000.0
# 2  2017-07-06 14:52:57.000000  2017-07-06 13:52:51.000000     20000.0
# 3  2017-07-27 19:00:41.000000  2017-07-27 18:00:35.000000     10000.0
# 4  2017-07-03 23:42:45.000000  2017-07-03 22:42:39.000000     40000.0
#
#    totaldue  termdays referredby good_bad_flag
# 0   34500.0        30        NaN          Good
# 1   17250.0        30        NaN          Good
# 2   22250.0        15        NaN          Good
# 3   11500.0        15        NaN          Good
# 4   44000.0        30        NaN          Good

# %%
perf_df.shape
# Out:
# (4368, 10)

# %%
perf_df.isna().sum()
# Out:
# customerid          0
# systemloanid        0
# loannumber          0
# approveddate        0
# creationdate        0
# loanamount          0
# totaldue            0
# termdays            0
# referredby       3781
# good_bad_flag       0
# dtype: int64

# %%
perf_df["customerid"].duplicated().sum()
# Out:
# 0

# %%
perf_df["referredby"] = perf_df["referredby"].fillna("Not referred")

# %%
perf_df.isna().sum()
# Out:
# customerid       0
# systemloanid     0
# loannumber       0
# approveddate     0
# creationdate     0
# loanamount       0
# totaldue         0
# termdays         0
# referredby       0
# good_bad_flag    0
# dtype: int64

# %%
perf_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4368 entries, 0 to 4367
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerid     4368 non-null   object
#  1   systemloanid   4368 non-null   int64
#  2   loannumber     4368 non-null   int64
#  3   approveddate   4368 non-null   object
#  4   creationdate   4368 non-null   object
#  5   loanamount     4368 non-null   float64
#  6   totaldue       4368 non-null   float64
#  7   termdays       4368 non-null   int64
#  8   referredby     4368 non-null   object
#  9   good_bad_flag  4368 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 341.4+ KB

# %%
demo_df = pd.read_csv("data/traindemographics.csv")
demo_df.head()
# Out:
#                          customerid                   birthdate  \
# 0  8a858e135cb22031015cbafc76964ebd  1973-10-10 00:00:00.000000
# 1  8a858e275c7ea5ec015c82482d7c3996  1986-01-21 00:00:00.000000
# 2  8a858e5b5bd99460015bdc95cd485634  1987-04-01 00:00:00.000000
# 3  8a858efd5ca70688015cabd1f1e94b55  1991-07-19 00:00:00.000000
# 4  8a858e785acd3412015acd48f4920d04  1982-11-22 00:00:00.000000
#
#   bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0           Savings       3.319219      6.528604           GT Bank
# 1           Savings       3.325598      7.119403     Sterling Bank
# 2           Savings       5.746100      5.563174     Fidelity Bank
# 3           Savings       3.362850      6.642485           GT Bank
# 4           Savings       8.455332     11.971410           GT Bank
#
#   bank_branch_clients employment_status_clients level_of_education_clients
# 0                 NaN                       NaN                        NaN
# 1                 NaN                 Permanent                        NaN
# 2                 NaN                       NaN                        NaN
# 3                 NaN                 Permanent                        NaN
# 4                 NaN                 Permanent                        NaN

# %%
demo_df.shape
# Out:
# (4346, 9)

# %%
demo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4346 entries, 0 to 4345
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  4346 non-null   object
#  1   birthdate                   4346 non-null   object
#  2   bank_account_type           4346 non-null   object
#  3   longitude_gps               4346 non-null   float64
#  4   latitude_gps                4346 non-null   float64
#  5   bank_name_clients           4346 non-null   object
#  6   bank_branch_clients         51 non-null     object
#  7   employment_status_clients   3698 non-null   object
#  8   level_of_education_clients  587 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 305.7+ KB

# %%
demo_df.isna().sum()
# Out:
# customerid                       0
# birthdate                        0
# bank_account_type                0
# longitude_gps                    0
# latitude_gps                     0
# bank_name_clients                0
# bank_branch_clients           4295
# employment_status_clients      648
# level_of_education_clients    3759
# dtype: int64

# %%
demo_df["customerid"].duplicated().sum()
# Out:
# 12

# %%
demo_df[demo_df["customerid"].duplicated()].sort_values(by="customerid")
# Out:
#                             customerid                   birthdate  \
# 1928  8a858e625c8d993a015c938f829f77ee  1988-12-20 00:00:00.000000
# 1090  8a858e6c5c88d145015c8b9627cd5a48  1979-09-30 00:00:00.000000
# 1996  8a858ec65cc6352b015cc64525ea0763  1985-01-30 00:00:00.000000
# 517   8a858edd57f790040157ffe9b6ed3fbb  1988-01-18 00:00:00.000000
# 4126  8a858f1e5baffcc9015bb02b505f180d  1983-04-06 00:00:00.000000
# 4266  8a858f1e5cc4bc81015cc548e1eb5206  1979-09-15 00:00:00.000000
# 776   8a858f965bb63a25015bbf63fd062e2e  1974-02-25 00:00:00.000000
# 4286  8a858f9f5679951a01567a5b90644817  1984-12-17 00:00:00.000000
# 1188  8a858fc75cd62882015cdaf2f4311b3f  1975-10-27 00:00:00.000000
# 159   8a858fca5c35df2c015c39ad8695343e  1980-11-26 00:00:00.000000
# 1480  8a858fe05d421ff4015d4c87d2a21ceb  1983-01-20 00:00:00.000000
# 1015  8a858fe65675195a015679452588279c  1982-08-01 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 1928           Savings       5.768333      5.561992        First Bank
# 1090           Savings       3.367008      6.497313     Sterling Bank
# 1996           Savings       3.845728      7.411737           GT Bank
# 517              Other       3.782563      7.171356        First Bank
# 4126           Savings       6.969350      4.818535           GT Bank
# 4266           Savings       6.285242      4.922719               UBA
# 776            Savings       3.936366      6.817958      Stanbic IBTC
# 4286           Savings       4.196662     12.429509       Access Bank
# 1188           Savings       7.437607      9.088935           GT Bank
# 159            Savings       3.352588      7.211089           GT Bank
# 1480           Savings       8.526960     12.023015         Skye Bank
# 1015           Savings       7.533646      9.046885               UBA
#
#      bank_branch_clients employment_status_clients level_of_education_clients
# 1928                 NaN                 Permanent                        NaN
# 1090                 NaN                 Permanent                        NaN
# 1996                 NaN                 Permanent                        NaN
# 517                  NaN                 Permanent                  Secondary
# 4126                 NaN                 Permanent                        NaN
# 4266                 NaN                 Permanent                        NaN
# 776                  NaN                 Permanent                        NaN
# 4286                 NaN                 Permanent                        NaN
# 1188                 NaN                 Permanent                        NaN
# 159                  NaN                 Permanent                        NaN
# 1480                 NaN                 Permanent                        NaN
# 1015                 NaN                 Permanent                        NaN

# %%
demo_df[demo_df["customerid"] == "8a858e625c8d993a015c938f829f77ee"]
# Out:
#                             customerid                   birthdate  \
# 1414  8a858e625c8d993a015c938f829f77ee  1988-12-20 00:00:00.000000
# 1928  8a858e625c8d993a015c938f829f77ee  1988-12-20 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 1414           Savings       5.768333      5.561992        First Bank
# 1928           Savings       5.768333      5.561992        First Bank
#
#      bank_branch_clients employment_status_clients level_of_education_clients
# 1414                 NaN                 Permanent                        NaN
# 1928                 NaN                 Permanent                        NaN

# %%
# Demographic data shouldn't be duplicated. Duplicate entries will be dropped
demo_df = demo_df.drop_duplicates()

# %%
demo_df.shape
# Out:
# (4334, 9)

# %%
demo_df["employment_status_clients"] = demo_df["employment_status_clients"].fillna("Unknown")

# %%
demo_df["employment_status_clients"].value_counts()
# Out:
# Permanent        3134
# Unknown           648
# Self-Employed     348
# Student           142
# Unemployed         57
# Retired             4
# Contract            1
# Name: employment_status_clients, dtype: int64

# %%
to_drop = ["level_of_education_clients", "bank_branch_clients"]

for column in to_drop:
    demo_df.pop(column)

# %%
demo_df.isna().sum()
# Out:
# customerid                   0
# birthdate                    0
# bank_account_type            0
# longitude_gps                0
# latitude_gps                 0
# bank_name_clients            0
# employment_status_clients    0
# dtype: int64

# %%
prev_df = pd.read_csv("data/trainprevloans.csv")
prev_df.head()
# Out:
#                          customerid  systemloanid  loannumber  \
# 0  8a2a81a74ce8c05d014cfb32a0da1049     301682320           2
# 1  8a2a81a74ce8c05d014cfb32a0da1049     301883808           9
# 2  8a2a81a74ce8c05d014cfb32a0da1049     301831714           8
# 3  8a8588f35438fe12015444567666018e     301861541           5
# 4  8a85890754145ace015429211b513e16     301941754           2
#
#                  approveddate                creationdate  loanamount  \
# 0  2016-08-15 18:22:40.000000  2016-08-15 17:22:32.000000     10000.0
# 1  2017-04-28 18:39:07.000000  2017-04-28 17:38:53.000000     10000.0
# 2  2017-03-05 10:56:25.000000  2017-03-05 09:56:19.000000     20000.0
# 3  2017-04-09 18:25:55.000000  2017-04-09 17:25:42.000000     10000.0
# 4  2017-06-17 09:29:57.000000  2017-06-17 08:29:50.000000     10000.0
#
#    totaldue  termdays                  closeddate referredby  \
# 0   13000.0        30  2016-09-01 16:06:48.000000        NaN
# 1   13000.0        30  2017-05-28 14:44:49.000000        NaN
# 2   23800.0        30  2017-04-26 22:18:56.000000        NaN
# 3   11500.0        15  2017-04-24 01:35:52.000000        NaN
# 4   11500.0        15  2017-07-14 21:18:43.000000        NaN
#
#                  firstduedate             firstrepaiddate
# 0  2016-09-14 00:00:00.000000  2016-09-01 15:51:43.000000
# 1  2017-05-30 00:00:00.000000  2017-05-26 00:00:00.000000
# 2  2017-04-04 00:00:00.000000  2017-04-26 22:03:47.000000
# 3  2017-04-24 00:00:00.000000  2017-04-24 00:48:43.000000
# 4  2017-07-03 00:00:00.000000  2017-07-14 21:08:35.000000

# %%
prev_df.shape
# Out:
# (18183, 12)

# %%
prev_df["customerid"].duplicated().sum()
# Out:
# 13824

# 2     2017-04-04 00:00:00.000000  2017-04-26 22:03:47.000000
# 55    2017-07-03 00:00:00.000000  2017-06-25 15:13:56.000000
# 56    2017-07-31 00:00:00.000000  2017-07-25 08:04:27.000000
# 57    2017-01-20 00:00:00.000000  2017-02-28 13:05:11.000000
# 1141  2016-11-07 00:00:00.000000  2016-11-07 08:14:34.000000
# 1142  2017-03-30 00:00:00.000000  2017-03-01 18:10:14.000000
# 1742  2016-09-08 00:00:00.000000  2016-08-15 08:34:14.000000
# 1743  2016-10-05 00:00:00.000000  2016-10-04 17:47:49.000000
# 1744  2016-12-07 00:00:00.000000  2016-12-21 11:35:37.000000

# %%
prev_df.isna().sum()
# Out:
# customerid             0
# systemloanid           0
# loannumber             0
# approveddate           0
# creationdate           0
# loanamount             0
# totaldue               0
# termdays               0
# closeddate             0
# referredby         17157
# firstduedate           0
# firstrepaiddate        0
# dtype: int64

# %%
prev_df["referredby"] = prev_df["referredby"].fillna("Not referred")

# %%
prev_df.isna().sum()
# Out:
# customerid         0
# systemloanid       0
# loannumber         0
# approveddate       0
# creationdate       0
# loanamount         0
# totaldue           0
# termdays           0
# closeddate         0
# referredby         0
# firstduedate       0
# firstrepaiddate    0
# dtype: int64

# %%
prev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18183 entries, 0 to 18182
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customerid       18183 non-null  object
#  1   systemloanid     18183 non-null  int64
#  2   loannumber       18183 non-null  int64
#  3   approveddate     18183 non-null  object
#  4   creationdate     18183 non-null  object
#  5   loanamount       18183 non-null  float64
#  6   totaldue         18183 non-null  float64
#  7   termdays         18183 non-null  int64
#  8   closeddate       18183 non-null  object
#  9   referredby       18183 non-null  object
#  10  firstduedate     18183 non-null  object
#  11  firstrepaiddate  18183 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 1.7+ MB

# %% [markdown]
# ### DATA MERGING

# %%
print("Shape of demographic data", demo_df.shape)
print("Shape of performance data", perf_df.shape)
print("Shape of previous loans data", prev_df.shape)
# Out:
# Shape of demographic data (4334, 7)
# Shape of performance data (4368, 10)
# Shape of previous loans data (18183, 12)

# %%
df1 = pd.merge(demo_df, perf_df, on="customerid", how="outer")
df1.head()
# Out:
#                          customerid                   birthdate  \
# 0  8a858e135cb22031015cbafc76964ebd  1973-10-10 00:00:00.000000
# 1  8a858e275c7ea5ec015c82482d7c3996  1986-01-21 00:00:00.000000
# 2  8a858e5b5bd99460015bdc95cd485634  1987-04-01 00:00:00.000000
# 3  8a858efd5ca70688015cabd1f1e94b55  1991-07-19 00:00:00.000000
# 4  8a858e785acd3412015acd48f4920d04  1982-11-22 00:00:00.000000
#
#   bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0           Savings       3.319219      6.528604           GT Bank
# 1           Savings       3.325598      7.119403     Sterling Bank
# 2           Savings       5.746100      5.563174     Fidelity Bank
# 3           Savings       3.362850      6.642485           GT Bank
# 4           Savings       8.455332     11.971410           GT Bank
#
#   employment_status_clients  systemloanid  loannumber  \
# 0                   Unknown   301964962.0         2.0
# 1                 Permanent   301972172.0         2.0
# 2                   Unknown   301976271.0         4.0
# 3                 Permanent   301997763.0         2.0
# 4                 Permanent           NaN         NaN
#
#                  approveddate                creationdate  loanamount  \
# 0  2017-07-05 14:29:48.000000  2017-07-05 13:29:42.000000     10000.0
# 1  2017-07-10 21:21:46.000000  2017-07-10 20:21:40.000000     10000.0
# 2  2017-07-13 15:40:27.000000  2017-07-13 14:40:19.000000     10000.0
# 3  2017-07-26 21:03:17.000000  2017-07-26 20:03:09.000000     10000.0
# 4                         NaN                         NaN         NaN
#
#    totaldue  termdays                        referredby good_bad_flag
# 0   13000.0      30.0  8a858899538ddb8e0153a780c56e34bb          Good
# 1   13000.0      30.0                      Not referred           Bad
# 2   13000.0      30.0                      Not referred          Good
# 3   11500.0      15.0                      Not referred          Good
# 4       NaN       NaN                               NaN           NaN

# %%
df1.shape
# Out:
# (5433, 16)

# %%
df1.isna().sum()
# Out:
# customerid                      0
# birthdate                    1099
# bank_account_type            1099
# longitude_gps                1099
# latitude_gps                 1099
# bank_name_clients            1099
# employment_status_clients    1099
# systemloanid                 1065
# loannumber                   1065
# approveddate                 1065
# creationdate                 1065
# loanamount                   1065
# totaldue                     1065
# termdays                     1065
# referredby                   1065
# good_bad_flag                1065
# dtype: int64

# %%
# 4359 unique customers
len(prev_df["customerid"].unique())
# Out:
# 4359

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5433 entries, 0 to 5432
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerid                 5433 non-null   object
#  1   birthdate                  4334 non-null   object
#  2   bank_account_type          4334 non-null   object
#  3   longitude_gps              4334 non-null   float64
#  4   latitude_gps               4334 non-null   float64
#  5   bank_name_clients          4334 non-null   object
#  6   employment_status_clients  4334 non-null   object
#  7   systemloanid               4368 non-null   float64
#  8   loannumber                 4368 non-null   float64
#  9   approveddate               4368 non-null   object
#  10  creationdate               4368 non-null   object
#  11  loanamount                 4368 non-null   float64
#  12  totaldue                   4368 non-null   float64
#  13  termdays                   4368 non-null   float64
#  14  referredby                 4368 non-null   object
#  15  good_bad_flag              4368 non-null   object
# dtypes: float64(7), object(9)
# memory usage: 721.6+ KB

# %%
# creat a data frame for the merge
df2frames = [df1, prev_df]

# %%
# use the concat function to perfomr a many-to-many merge since there are duplicate customer id
dftrain = pd.concat(df2frames)

# %%
dftrain.head()
# Out:
#                          customerid                   birthdate  \
# 0  8a858e135cb22031015cbafc76964ebd  1973-10-10 00:00:00.000000
# 1  8a858e275c7ea5ec015c82482d7c3996  1986-01-21 00:00:00.000000
# 2  8a858e5b5bd99460015bdc95cd485634  1987-04-01 00:00:00.000000
# 3  8a858efd5ca70688015cabd1f1e94b55  1991-07-19 00:00:00.000000
# 4  8a858e785acd3412015acd48f4920d04  1982-11-22 00:00:00.000000
#
#   bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0           Savings       3.319219      6.528604           GT Bank
# 1           Savings       3.325598      7.119403     Sterling Bank
# 2           Savings       5.746100      5.563174     Fidelity Bank
# 3           Savings       3.362850      6.642485           GT Bank
# 4           Savings       8.455332     11.971410           GT Bank
#
#   employment_status_clients  systemloanid  loannumber  \
# 0                   Unknown   301964962.0         2.0
# 1                 Permanent   301972172.0         2.0
# 2                   Unknown   301976271.0         4.0
# 3                 Permanent   301997763.0         2.0
# 4                 Permanent           NaN         NaN
#
#                  approveddate                creationdate  loanamount  \
# 0  2017-07-05 14:29:48.000000  2017-07-05 13:29:42.000000     10000.0
# 1  2017-07-10 21:21:46.000000  2017-07-10 20:21:40.000000     10000.0
# 2  2017-07-13 15:40:27.000000  2017-07-13 14:40:19.000000     10000.0
# 3  2017-07-26 21:03:17.000000  2017-07-26 20:03:09.000000     10000.0
# 4                         NaN                         NaN         NaN
#
#    totaldue  termdays                        referredby good_bad_flag  \
# 0   13000.0      30.0  8a858899538ddb8e0153a780c56e34bb          Good
# 1   13000.0      30.0                      Not referred           Bad
# 2   13000.0      30.0                      Not referred          Good
# 3   11500.0      15.0                      Not referred          Good
# 4       NaN       NaN                               NaN           NaN
#
#   closeddate firstduedate firstrepaiddate
# 0        NaN          NaN             NaN
# 1        NaN          NaN             NaN
# 2        NaN          NaN             NaN
# 3        NaN          NaN             NaN
# 4        NaN          NaN             NaN

# %%
dftrain.shape
# Out:
# (23616, 19)

# %%
#List of columns in demographic data

demo_data = ['customerid', 'birthdate', 'bank_account_type', 'longitude_gps', 'latitude_gps', 'bank_name_clients', 'employment_status_clients' ]

# %%
for i in demo_data:
    dftrain[i] = dftrain.groupby(['customerid'])[i].ffill()

# %% [markdown]
# Fill up demographic data from previous values in the table

# %%
dftrain.isna().sum()
# Out:
# customerid                       0
# birthdate                     5609
# bank_account_type             5609
# longitude_gps                 5609
# latitude_gps                  5609
# bank_name_clients             5609
# employment_status_clients     5609
# systemloanid                  1065
# loannumber                    1065
# approveddate                  1065
# creationdate                  1065
# loanamount                    1065
# totaldue                      1065
# termdays                      1065
# referredby                    1065
# good_bad_flag                19248
# closeddate                    5433
# firstduedate                  5433
# firstrepaiddate               5433
# dtype: int64

# %%
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23616 entries, 0 to 18182
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerid                 23616 non-null  object
#  1   birthdate                  18007 non-null  object
#  2   bank_account_type          18007 non-null  object
#  3   longitude_gps              18007 non-null  float64
#  4   latitude_gps               18007 non-null  float64
#  5   bank_name_clients          18007 non-null  object
#  6   employment_status_clients  18007 non-null  object
#  7   systemloanid               22551 non-null  float64
#  8   loannumber                 22551 non-null  float64
#  9   approveddate               22551 non-null  object
#  10  creationdate               22551 non-null  object
#  11  loanamount                 22551 non-null  float64
#  12  totaldue                   22551 non-null  float64
#  13  termdays                   22551 non-null  float64
#  14  referredby                 22551 non-null  object
#  15  good_bad_flag              4368 non-null   object
#  16  closeddate                 18183 non-null  object
#  17  firstduedate               18183 non-null  object
#  18  firstrepaiddate            18183 non-null  object
# dtypes: float64(7), object(12)
# memory usage: 3.6+ MB

# %%
#To determine the number of null values
dftrain.isna().sum()
# Out:
# customerid                       0
# birthdate                     5609
# bank_account_type             5609
# longitude_gps                 5609
# latitude_gps                  5609
# bank_name_clients             5609
# employment_status_clients     5609
# systemloanid                  1065
# loannumber                    1065
# approveddate                  1065
# creationdate                  1065
# loanamount                    1065
# totaldue                      1065
# termdays                      1065
# referredby                    1065
# good_bad_flag                19248
# closeddate                    5433
# firstduedate                  5433
# firstrepaiddate               5433
# dtype: int64

# %% [markdown]
# We can see that majority of our data does not have demographic data. But some of the customers does not have loan data so we have to remove those

# %%
loancount = dftrain.groupby('customerid')['loannumber'].count().reset_index(name = 'count').sort_values(['count'], ascending= False)
loancount
# Out:
#                             customerid  count
# 4089  8a858f7d5578012a01557ea194d94948     27
# 1114  8a858e4456ced8470156d73452f85335     23
# 117   8a85888c548fb3d50154947fe59c32cf     22
# 142   8a858899538ddb8e0153a780c56e34bb     22
# 111   8a85886f54517ee0015470749d3c3ce7     22
# ...                                ...    ...
# 2059  8a858eaa5bed957a015bed9d7eae048b      0
# 4307  8a858f98560bbe1101560ccaa0f8413b      0
# 2067  8a858eac59b14c020159b1c6a26a5569      0
# 2073  8a858eac5ad81473015adb8fd64e2636      0
# 5432  8addcb0645aff34b0145b25fe1616ee0      0
#
# [5433 rows x 2 columns]

# %% [markdown]
# From the results above, we can see that some customerid have a loan number of 0. We have to eliminate them first

# %%
emptyloancount= loancount[loancount['count']==0]
emptyloancount
# Out:
#                             customerid  count
# 131   8a85889853f0fbaa01540f0d556f0ec3      0
# 5116  8a858fde56eb02280156f59b976d46c0      0
# 4849  8a858fc75cd62882015cd635fb7f0393      0
# 746   8a858e175872e14e0158760dbfcc5d06      0
# 751   8a858e1856aa901b0156ae8f6ada1a00      0
# ...                                ...    ...
# 2059  8a858eaa5bed957a015bed9d7eae048b      0
# 4307  8a858f98560bbe1101560ccaa0f8413b      0
# 2067  8a858eac59b14c020159b1c6a26a5569      0
# 2073  8a858eac5ad81473015adb8fd64e2636      0
# 5432  8addcb0645aff34b0145b25fe1616ee0      0
#
# [1065 rows x 2 columns]

# %%
index_todrop = dftrain[dftrain['loannumber'].isna()].index
index_todrop
# Out:
# Int64Index([   4,    5,    7,    9,   13,   19,   24,   27,   28,   31,
#             ...
#             4309, 4312, 4314, 4317, 4320, 4321, 4322, 4331, 4332, 4333],
#            dtype='int64', length=1065)

# %%
dftrain.drop(index_todrop, inplace = True)

# %%
dftrain
# Out:
#                              customerid                   birthdate  \
# 0      8a858e135cb22031015cbafc76964ebd  1973-10-10 00:00:00.000000
# 1      8a858e275c7ea5ec015c82482d7c3996  1986-01-21 00:00:00.000000
# 2      8a858e5b5bd99460015bdc95cd485634  1987-04-01 00:00:00.000000
# 3      8a858efd5ca70688015cabd1f1e94b55  1991-07-19 00:00:00.000000
# 6      8a858ea05a859123015a8892914d15b7  1990-07-21 00:00:00.000000
# ...                                 ...                         ...
# 18178  8a858899538ddb8e0153a2b555421fc5  1987-06-28 00:00:00.000000
# 18179  8a858899538ddb8e0153a2b555421fc5  1987-06-28 00:00:00.000000
# 18180  8a858899538ddb8e0153a2b555421fc5  1987-06-28 00:00:00.000000
# 18181  8a858f0656b7820c0156c92ca3ba436f                         NaN
# 18182  8a858faf5679a838015688de3028143d  1989-04-10 00:00:00.000000
#
#       bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 6                             NaN
# ...                           ...
# 18178  2016-05-13 18:05:07.000000
# 18179  2016-12-13 15:53:48.000000
# 18180  2016-07-09 15:23:56.000000
# 18181  2016-10-15 10:02:45.000000
# 18182  2016-09-29 19:35:55.000000
#
# [21486 rows x 19 columns]

# %% [markdown]
# The rows that does not have values for closeddate, firstduedat and firstrepaiddate are the new data that we want to predict. I will try to save it as a separate file,
# then I will delete it from the merged data

# %%
index_todrop1 = dftrain[dftrain['closeddate'].isna()]
index_todrop1.isna().sum()
# Out:
# customerid                      0
# birthdate                    1099
# bank_account_type            1099
# longitude_gps                1099
# latitude_gps                 1099
# bank_name_clients            1099
# employment_status_clients    1099
# systemloanid                    0
# loannumber                      0
# approveddate                    0
# creationdate                    0
# loanamount                      0
# totaldue                        0
# termdays                        0
# referredby                      0
# good_bad_flag                   0
# closeddate                   4368
# firstduedate                 4368
# firstrepaiddate              4368
# dtype: int64

# %%
to_drop1 = index_todrop1.index

# %%
dftrain.drop(to_drop1, inplace = True)

# %%
dftrain
# Out:
#                              customerid                   birthdate  \
# 5433   8a858f255ca276c5015ca294645c08af  1983-10-30 00:00:00.000000
# 5434   8a858f3355ae6a610155c1daebe61b76                         NaN
# 5435   8a858f3355ae6a610155c1daebe61b76                         NaN
# 5436   8a858f3355ae6a610155c1daebe61b76                         NaN
# 5437   8a858f465668e3d601568add9c6a4fe0  1992-03-03 00:00:00.000000
# ...                                 ...                         ...
# 18178  8a858899538ddb8e0153a2b555421fc5  1987-06-28 00:00:00.000000
# 18179  8a858899538ddb8e0153a2b555421fc5  1987-06-28 00:00:00.000000
# 18180  8a858899538ddb8e0153a2b555421fc5  1987-06-28 00:00:00.000000
# 18181  8a858f0656b7820c0156c92ca3ba436f                         NaN
# 18182  8a858faf5679a838015688de3028143d  1989-04-10 00:00:00.000000
#
#       bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 5433            Savings       4.525736      7.754208               UBA
# 5434                NaN            NaN           NaN               NaN
# 5435                NaN            NaN           NaN               NaN
# 5436                NaN            NaN           NaN               NaN
# 5437              Other       3.585857      6.490853      Diamond Bank
# ...                 ...            ...           ...               ...
# 18178           Savings       3.378536      6.548313       Zenith Bank
# 18179           Savings       3.378536      6.548313       Zenith Bank
# 18180           Savings       3.378536      6.548313       Zenith Bank
# 18181               NaN            NaN           NaN               NaN
# 18182             Other      11.178342     10.297090     Fidelity Bank
#
#       employment_status_clients  systemloanid  loannumber  \
# 5433                  Permanent   301937638.0         1.0
# 5434                        NaN   301740144.0         6.0
# 5435                        NaN   301756269.0         7.0
# 5436                        NaN   301848853.0        11.0
# 5437                  Permanent   301821221.0         3.0
# ...                         ...           ...         ...
# 18178                 Permanent   301611754.0         2.0
# 18179                 Permanent   301761267.0         9.0
# 18180                 Permanent   301631653.0         4.0
# 18181                       NaN   301697691.0         1.0
# 18182                   Student   301715255.0         2.0
#
#                      approveddate                creationdate  loanamount  \
# 5433   2017-06-13 19:16:32.000000  2017-06-13 18:15:24.000000     10000.0
# 5434   2016-10-09 09:50:56.000000  2016-10-09 08:50:33.000000     30000.0
# 5435   2016-11-08 17:17:20.000000  2016-11-08 16:17:10.000000     30000.0
# %% [markdown]
# I want to see if I can find any way to differentiate the data with wierd amount of null values and see how to clean them

# %%
dftrain.isna().sum()
# Out:
# customerid                       0
# birthdate                     3157
# bank_account_type             3157
# longitude_gps                 3157
# latitude_gps                  3157
# bank_name_clients             3157
# employment_status_clients     3157
# systemloanid                     0
# loannumber                       0
# approveddate                     0
# creationdate                     0
# loanamount                       0
# totaldue                         0
# termdays                         0
# referredby                       0
# good_bad_flag                12750
# closeddate                       0
# firstduedate                     0
# firstrepaiddate                  0
# dtype: int64

# %%
dftrain.groupby('customerid')['loannumber'].count().reset_index(name = 'count').sort_values(['count'], ascending= False)
# Out:
#                             customerid  count
# 744   8a858e4456ced8470156d73452f85335     22
# 3442  8a858fe5569398920156a3a9a77b5d02     21
# 311   8a8589b953d0be470153e043e57e2d79     20
# 165   8a858900536a043401537e702ff74eac     19
# 840   8a858e5856b7840c0156c298b5d35422     18
# ...                                ...    ...
# 2415  8a858f4e5ca72981015ca8ad2f9e5e4e      1
# 2414  8a858f4e5ca72981015ca72f23a303a3      1
# 2413  8a858f4e5ba5e8d3015baa225ee45742      1
# 1042  8a858e6f5668e017015684c4a4305d0a      1
# 1813  8a858ef25c8393f8015c83e086201108      1
#
# [3627 rows x 2 columns]

# %%
dftrain[dftrain['customerid']== '8a858f7d5578012a01557ea194d94948'].sort_values(by = 'loannumber', ascending = False)
# Out:
#                              customerid                   birthdate  \
# 15547  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 15544  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 14173  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 15542  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 15543  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 15548  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 14178  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 14177  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 15545  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 14176  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 14174  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 14175  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
# 15546  8a858f7d5578012a01557ea194d94948  1987-08-05 00:00:00.000000
#
#       bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 15547             Other       7.408563     10.464973               UBA
# 15544             Other       7.408563     10.464973               UBA
# 14173             Other       7.408563     10.464973               UBA
# 15542             Other       7.408563     10.464973               UBA
# 15543             Other       7.408563     10.464973               UBA
# 15548             Other       7.408563     10.464973               UBA
# 14178             Other       7.408563     10.464973               UBA
# 14177             Other       7.408563     10.464973               UBA
# 15545             Other       7.408563     10.464973               UBA
# 14176             Other       7.408563     10.464973               UBA
# 14174             Other       7.408563     10.464973               UBA
# 14175             Other       7.408563     10.464973               UBA
# 15546             Other       7.408563     10.464973               UBA
#
#       employment_status_clients  systemloanid  loannumber  \
# 15547                 Permanent   301952989.0        26.0
# 15544                 Permanent   301945496.0        25.0
# 14173                 Permanent   301836219.0        18.0
# 15542                 Permanent   301797622.0        14.0
# 15543                 Permanent   301797471.0        11.0
# 15548                 Permanent   301797398.0        10.0
# 14178                 Permanent   301797333.0         9.0
# 14177                 Permanent   301797263.0         7.0
# 15545                 Permanent   301797243.0         6.0
# 14176                 Permanent   301790327.0         4.0
# 14174                 Permanent   301788579.0         3.0
# 14175                 Permanent   301765599.0         2.0
# 15546                 Permanent   301688861.0         1.0
#
#                      approveddate                creationdate  loanamount  \
# 15547  2017-06-27 07:20:13.000000  2017-06-27 06:20:06.000000     10000.0
# 15544  2017-06-20 19:54:10.000000  2017-06-20 18:53:03.000000     10000.0
a858899538ddb8e015390510b321f08     301998974           4      40:48.0
# 1  8a858959537a097401537a4e316e25f7     301963615          10      43:40.0
# 2  8a8589c253ace09b0153af6ba58f1f31     301982236           6      15:11.0
# 3  8a858e095aae82b7015aae86ca1e030b     301971730           8      00:54.0
# 4  8a858e225a28c713015a30db5c48383d     301959177           4      04:33.0
#
#   creationdate  loanamount  totaldue  termdays referredby
# 0      39:35.0       10000   12250.0        30        NaN
# 1      42:34.0       40000   44000.0        30        NaN
# 2      15:04.0       20000   24500.0        30        NaN
# 3      00:49.0       30000   34500.0        30        NaN
# 4      04:27.0       20000   24500.0        30        NaN

# %%
perf_tst.shape
# Out:
# (1450, 9)

# %%
perf_tst.isna().sum()
# Out:
# customerid         0
# systemloanid       0
# loannumber         0
# approveddate       0
# creationdate       0
# loanamount         0
# totaldue           0
# termdays           0
# referredby      1266
# dtype: int64

# %%
perf_tst["customerid"].duplicated().sum()
# Out:
# 0

# %%
perf_tst["referredby"] = perf_tst["referredby"].fillna("Not referred")

# %%
perf_tst.isna().sum()
# Out:
# customerid      0
# systemloanid    0
# loannumber      0
# approveddate    0
# creationdate    0
# loanamount      0
# totaldue        0
# termdays        0
# referredby      0
# dtype: int64

# %%
perf_tst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customerid    1450 non-null   object
#  1   systemloanid  1450 non-null   int64
#  2   loannumber    1450 non-null   int64
#  3   approveddate  1450 non-null   object
#  4   creationdate  1450 non-null   object
#  5   loanamount    1450 non-null   int64
#  6   totaldue      1450 non-null   float64
#  7   termdays      1450 non-null   int64
#  8   referredby    1450 non-null   object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 102.1+ KB

# %%
demo_tst = pd.read_csv("data/testdemographics.csv")
demo_df.head()
# Out:
#                          customerid                   birthdate  \
# 0  8a858e135cb22031015cbafc76964ebd  1973-10-10 00:00:00.000000
# 1  8a858e275c7ea5ec015c82482d7c3996  1986-01-21 00:00:00.000000
# 2  8a858e5b5bd99460015bdc95cd485634  1987-04-01 00:00:00.000000
# 3  8a858efd5ca70688015cabd1f1e94b55  1991-07-19 00:00:00.000000
# 4  8a858e785acd3412015acd48f4920d04  1982-11-22 00:00:00.000000
#
#   bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0           Savings       3.319219      6.528604           GT Bank
# 1           Savings       3.325598      7.119403     Sterling Bank
# 2           Savings       5.746100      5.563174     Fidelity Bank
# 3           Savings       3.362850      6.642485           GT Bank
# 4           Savings       8.455332     11.971410           GT Bank
#
#   employment_status_clients
# 0                   Unknown
# 1                 Permanent
# 2                   Unknown
# 3                 Permanent
# 4                 Permanent

# %%
demo_tst.shape
# Out:
# (1487, 9)

# %%
demo_tst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1487 entries, 0 to 1486
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  1487 non-null   object
#  1   birthdate                   1487 non-null   object
#  2   bank_account_type           1487 non-null   object
#  3   longitude_gps               1487 non-null   float64
#  4   latitude_gps                1487 non-null   float64
#  5   bank_name_clients           1487 non-null   object
#  6   bank_branch_clients         14 non-null     object
#  7   employment_status_clients   1270 non-null   object
#  8   level_of_education_clients  210 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 104.7+ KB

# %%
demo_tst.isna().sum()
# Out:
# customerid                       0
# birthdate                        0
# bank_account_type                0
# longitude_gps                    0
# latitude_gps                     0
# bank_name_clients                0
# bank_branch_clients           1473
# employment_status_clients      217
# level_of_education_clients    1277
# dtype: int64

# %%
demo_tst["customerid"].duplicated().sum()
# Out:
# 3

# %%
demo_tst[demo_tst["customerid"].duplicated()].sort_values(by="customerid")
# Out:
#                             customerid                   birthdate  \
# 502   8a8588b75438f49901544510041e0951  1980-01-16 00:00:00.000000
# 810   8a858e885b68546c015b7238f22027ba  1975-06-18 00:00:00.000000
# 1285  8a858f2e5c699f3a015c6e10b65607c9  1978-06-20 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 502              Other       3.342808      6.542411       Zenith Bank
# 810            Savings       3.353123      6.587837        First Bank
# 1285           Savings       3.325513      6.500937           GT Bank
#
#      bank_branch_clients employment_status_clients level_of_education_clients
# 502                  NaN                 Permanent                   Graduate
# 810                  NaN                 Permanent                        NaN
# 1285                 NaN                 Permanent                        NaN

# %%
# Demographic data Duplicate entries will be dropped
demo_tst = demo_tst.drop_duplicates()

# %%
demo_tst.shape
# Out:
# (1484, 9)

# %%
#demo_tst["employment_status_clients"] = demo_tst["employment_status_clients"].fillna("Unknown")
demo_tst["employment_status_clients"].fillna("Unknown", inplace = True)

# %%
demo_tst["employment_status_clients"].value_counts()
# Out:
# Permanent        1071
# Unknown           217
# Self-Employed     122
# Student            47
# Unemployed         22
# Retired             4
# Contract            1
# Name: employment_status_clients, dtype: int64

# %%
to_drop = ["level_of_education_clients", "bank_branch_clients"]

for column in to_drop:
    demo_tst.pop(column)

# %%
demo_tst.isna().sum()
# Out:
# customerid                   0
# birthdate                    0
# bank_account_type            0
# longitude_gps                0
# latitude_gps                 0
# bank_name_clients            0
# employment_status_clients    0
# dtype: int64

# %%
prev_tst = pd.read_csv("data/testprevloans.csv")
prev_tst.head()
# Out:
#                          customerid  systemloanid  loannumber  \
# 0  8a858899538ddb8e015390510b321f08     301621635           3
# 1  8a858959537a097401537a4e316e25f7     301810201           5
# 2  8a858959537a097401537a4e316e25f7     301831255           6
# 3  8a8589c253ace09b0153af6ba58f1f31     301627292           3
# 4  8a8589c253ace09b0153af6ba58f1f31     301621095           2
#
#                  approveddate                creationdate  loanamount  \
# 0  2016-05-17 10:37:00.000000  2016-05-17 09:36:55.000000     10000.0
# 1  2017-02-04 21:28:59.000000  2017-02-04 20:28:52.000000     30000.0
# 2  2017-03-04 10:28:22.000000  2017-03-04 09:28:16.000000     30000.0
# 3  2016-06-02 14:27:14.000000  2016-06-02 13:27:08.000000     10000.0
# 4  2016-05-16 09:13:12.000000  2016-05-16 08:13:04.000000     10000.0
#
#    totaldue  termdays                  closeddate referredby  \
# 0   13000.0        30  2016-06-17 00:04:15.000000        NaN
# 1   36800.0        60  2017-03-02 16:22:58.000000        NaN
# 2   34400.0        30  2017-04-02 00:44:24.000000        NaN
# 3   13000.0        30  2016-07-04 11:34:04.000000        NaN
# 8                                  NaN  2017-07-05 00:00:00.000000
# 10                                 NaN  2017-01-09 00:00:00.000000
# 15                                 NaN  2017-07-24 00:00:00.000000
# ...                                ...                         ...
# 5900                               NaN  2017-06-28 00:00:00.000000
# 5901  8a858e645755e62201575e72c8b77fd5  2017-05-30 00:00:00.000000
# 5902  8a858e4f5929c3df0159420645f46f55  2017-05-09 00:00:00.000000
# 5903                               NaN  2017-05-02 00:00:00.000000
# 5905                               NaN  2017-06-02 00:00:00.000000
#
#                  firstrepaiddate
# 2     2017-04-01 21:29:46.000000
# 4     2016-06-01 15:22:34.000000
# 8     2017-07-03 18:17:24.000000
# 10    2017-01-20 14:20:01.000000
# 15    2017-07-24 09:40:46.000000
# ...                          ...
# 5900  2017-06-30 20:23:26.000000
# 5901  2017-05-31 11:29:02.000000
# 5902  2017-05-02 22:11:54.000000
# 5903  2017-04-25 19:17:33.000000
# 5905  2017-06-01 21:50:07.000000
#
# [4465 rows x 12 columns]

# %%
#prev_tst[prev_tst["customerid"] == "8a2a81a74ce8c05d014cfb32a0da1049"]

# %%
prev_tst.isna().sum()
# Out:
# customerid            0
# systemloanid          0
# loannumber            0
# approveddate          0
# creationdate          0
# loanamount            0
# totaldue              0
# termdays              0
# closeddate            0
# referredby         5582
# firstduedate          0
# firstrepaiddate       0
# dtype: int64

# %%
prev_tst["referredby"] = prev_tst["referredby"].fillna("Not referred")

# %%
prev_tst.isna().sum()
# Out:
# customerid         0
# systemloanid       0
# loannumber         0
# approveddate       0
# creationdate       0
# loanamount         0
# totaldue           0
# termdays           0
# closeddate         0
# referredby         0
# firstduedate       0
# firstrepaiddate    0
# dtype: int64

# %%
prev_tst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5907 entries, 0 to 5906
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customerid       5907 non-null   object
#  1   systemloanid     5907 non-null   int64
#  2   loannumber       5907 non-null   int64
#  3   approveddate     5907 non-null   object
#  4   creationdate     5907 non-null   object
#  5   loanamount       5907 non-null   float64
#  6   totaldue         5907 non-null   float64
#  7   termdays         5907 non-null   int64
#  8   closeddate       5907 non-null   object
#  9   referredby       5907 non-null   object
#  10  firstduedate     5907 non-null   object
#  11  firstrepaiddate  5907 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 553.9+ KB

# %% [markdown]
# ## TEST DATA MERGING

# %%
print("Shape of test demographic data", demo_tst.shape)
print("Shape of test performance data", perf_tst.shape)
print("Shape of test previous loans data", prev_tst.shape)
# Out:
# Shape of test demographic data (1484, 7)
# Shape of test performance data (1450, 9)
# Shape of test previous loans data (5907, 12)

# %%
tstdf1 = pd.merge(demo_tst, perf_tst, on="customerid", how="outer")
tstdf1.head()
# Out:
#                          customerid                   birthdate  \
# 0  8a858f305c8dd672015c93b1db645db4  1976-08-28 00:00:00.000000
# 1  8a858f085a477386015a47fb049e49ca  1978-06-23 00:00:00.000000
# 2  8a858e6f5cd5e874015cd6f5634c39ad  1984-04-04 00:00:00.000000
# 3  8a858e9d5bfd7037015bfdab79f61305  1983-05-28 00:00:00.000000
# 4  8a858fde56eb02280156eb6dafc128ac  1982-03-29 00:00:00.000000
#
#   bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0           Savings       5.296628      7.593965     Heritage Bank
# 1           Savings       3.294513      6.596602               UBA
# 2           Savings       8.501912      7.729364        First Bank
# 3           Savings       3.318904      6.681595               UBA
# 4           Savings       6.354624      4.949031        First Bank
#
#   employment_status_clients  systemloanid  loannumber approveddate  \
# 0                 Permanent   301992953.0         2.0      36:45.0
# 1                 Permanent           NaN         NaN          NaN
# 2                 Permanent           NaN         NaN          NaN
# 3                 Permanent           NaN         NaN          NaN
# 4             Self-Employed   301997095.0        14.0      31:11.0
#
#   creationdate  loanamount  totaldue  termdays    referredby
# 0      36:38.0     10000.0   11500.0      15.0  Not referred
# 1          NaN         NaN       NaN       NaN           NaN
# 2          NaN         NaN       NaN       NaN           NaN
# 3          NaN         NaN       NaN       NaN           NaN
# 4      30:01.0     40000.0   44000.0      30.0  Not referred

# %%
tstdf1.shape
# Out:
# (2549, 15)

# %%
tstdf1.isna().sum()
# Out:
# customerid                      0
# birthdate                    1065
# bank_account_type            1065
# longitude_gps                1065
# latitude_gps                 1065
# bank_name_clients            1065
# employment_status_clients    1065
# systemloanid                 1099
# loannumber                   1099
# approveddate                 1099
# creationdate                 1099
# loanamount                   1099
# totaldue                     1099
# termdays                     1099
# referredby                   1099
# dtype: int64

# %%
# 4359 unique customers
len(prev_tst["customerid"].unique())
# Out:
# 1442

# %%
tstdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2549 entries, 0 to 2548
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerid                 2549 non-null   object
#  1   birthdate                  1484 non-null   object
#  2   bank_account_type          1484 non-null   object
#  3   longitude_gps              1484 non-null   float64
#  4   latitude_gps               1484 non-null   float64
#  5   bank_name_clients          1484 non-null   object
#  6   employment_status_clients  1484 non-null   object
#  7   systemloanid               1450 non-null   float64
#  8   loannumber                 1450 non-null   float64
#  9   approveddate               1450 non-null   object
#  10  creationdate               1450 non-null   object
#  11  loanamount                 1450 non-null   float64
#  12  totaldue                   1450 non-null   float64
#  13  termdays                   1450 non-null   float64
#  14  referredby                 1450 non-null   object
# dtypes: float64(7), object(8)
# memory usage: 318.6+ KB

# %%
# create a data frame for the merged test data
tstdf2frames = [tstdf1, prev_tst]

# %%
# use the concat function to perfomr a many-to-many merge since there are duplicate customer id
dftest = pd.concat(tstdf2frames)

# %%
dftest.head()
# Out:
#                          customerid                   birthdate  \
# 0  8a858f305c8dd672015c93b1db645db4  1976-08-28 00:00:00.000000
# 1  8a858f085a477386015a47fb049e49ca  1978-06-23 00:00:00.000000
# 2  8a858e6f5cd5e874015cd6f5634c39ad  1984-04-04 00:00:00.000000
# 3  8a858e9d5bfd7037015bfdab79f61305  1983-05-28 00:00:00.000000
# 4  8a858fde56eb02280156eb6dafc128ac  1982-03-29 00:00:00.000000
#
#   bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0           Savings       5.296628      7.593965     Heritage Bank
# 1           Savings       3.294513      6.596602               UBA
# 2           Savings       8.501912      7.729364        First Bank
# 3           Savings       3.318904      6.681595               UBA
# 4           Savings       6.354624      4.949031        First Bank
#
#   employment_status_clients  systemloanid  loannumber approveddate  \
# 0                 Permanent   301992953.0         2.0      36:45.0
# 1                 Permanent           NaN         NaN          NaN
# 2                 Permanent           NaN         NaN          NaN
# 3                 Permanent           NaN         NaN          NaN
# 4             Self-Employed   301997095.0        14.0      31:11.0
#
#   creationdate  loanamount  totaldue  termdays    referredby closeddate  \
# 0      36:38.0     10000.0   11500.0      15.0  Not referred        NaN
# 1          NaN         NaN       NaN       NaN           NaN        NaN
# 2          NaN         NaN       NaN       NaN           NaN        NaN
# 3          NaN         NaN       NaN       NaN           NaN        NaN
# 4      30:01.0     40000.0   44000.0      30.0  Not referred        NaN
#
#   firstduedate firstrepaiddate
# 0          NaN             NaN
# 1          NaN             NaN
# 2          NaN             NaN
# 3          NaN             NaN
# 4          NaN             NaN

# %%
dftest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8456 entries, 0 to 5906
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerid                 8456 non-null   object
#  1   birthdate                  1484 non-null   object
#  2   bank_account_type          1484 non-null   object
#  3   longitude_gps              1484 non-null   float64
#  4   latitude_gps               1484 non-null   float64
#  5   bank_name_clients          1484 non-null   object
#  6   employment_status_clients  1484 non-null   object
#  7   systemloanid               7357 non-null   float64
#  8   loannumber                 7357 non-null   float64
#  9   approveddate               7357 non-null   object
#  10  creationdate               7357 non-null   object
#  11  loanamount                 7357 non-null   float64
#  12  totaldue                   7357 non-null   float64
#  13  termdays                   7357 non-null   float64
#  14  referredby                 7357 non-null   object
#  15  closeddate                 5907 non-null   object
#  16  firstduedate               5907 non-null   object
#  17  firstrepaiddate            5907 non-null   object
# dtypes: float64(7), object(11)
# memory usage: 1.2+ MB

# %%
dftest.isna().sum()
# Out:
# customerid                      0
# birthdate                    6972
# bank_account_type            6972
# longitude_gps                6972
# latitude_gps                 6972
# bank_name_clients            6972
# employment_status_clients    6972
# systemloanid                 1099
# loannumber                   1099
# approveddate                 1099
# creationdate                 1099
# loanamount                   1099
# totaldue                     1099
# termdays                     1099
# referredby                   1099
# closeddate                   2549
# firstduedate                 2549
# firstrepaiddate              2549
# dtype: int64

# %%
for i in demo_data:
    dftest[i] = dftest.groupby(['customerid'])[i].ffill()

# %%
# dftest.isna().sum()
# Out:
# customerid                      0
# birthdate                    5367
# bank_account_type            5367
# longitude_gps                5367
# latitude_gps                 5367
# bank_name_clients            5367
# employment_status_clients    5367
# systemloanid                 1099
# loannumber                   1099
# approveddate                 1099
# creationdate                 1099
# loanamount                   1099
# totaldue                     1099
# termdays                     1099
# referredby                   1099
# closeddate                   2549
# firstduedate                 2549
# firstrepaiddate              2549
# dtype: int64

# %%
loancount1 = dftest.groupby('customerid')['loannumber'].count().reset_index(name = 'count').sort_values(['count'], ascending= False)
loancount1
# Out:
#                             customerid  count
# 2509  8a858ff554e290e10154fe4e6b3f648c     34
# 2407  8a858fdd54d4dd160154e1edcb6d7596     21
# 1454  8a858f1554e29449015505ceef786df0     19
# 93    8a8588d653a915270153ab10232e304f     19
# 183   8a858966538deb190153957484683e67     18
# ...                                ...    ...
# 827   8a858e7c587f3319015882b4fa1a157a      0
# 1710  8a858f4156939c3c01569eb58e93629a      0
# 828   8a858e7c588604a4015895a4d8541dea      0
# 1708  8a858f4156939c3c015693a5a85504cb      0
# 0     8a1edbf14734127f0147356fdb1b1eb2      0
#
# [2549 rows x 2 columns]

# %%
emptyloancount1= loancount1[loancount1['count']==0]
emptyloancount1
# Out:
#                             customerid  count
# 2131  8a858fa45bd95e9a015be29a6b136061      0
# 408   8a858e205bcee61c015bcf7dfcf3355b      0
# 2193  8a858faf56939fea01569d9c10415018      0
# 404   8a858e1e54e2aa5a0154e31e842130b6      0
# 2143  8a858fa7590af88501591230cd1c34b0      0
# ...                                ...    ...
# 827   8a858e7c587f3319015882b4fa1a157a      0
# 1710  8a858f4156939c3c01569eb58e93629a      0
# 828   8a858e7c588604a4015895a4d8541dea      0
# 1708  8a858f4156939c3c015693a5a85504cb      0
# 0     8a1edbf14734127f0147356fdb1b1eb2      0
#
# [1099 rows x 2 columns]

# %%
index_todrop2 = dftest[dftest['loannumber'].isna()].index
index_todrop2
# Out:
# Int64Index([], dtype='int64')

# %%
dftest.drop(index_todrop1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-9723803e90dd> in <module>
# ----> 1 dftest.drop(index_todrop1, inplace = True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4205                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    4206                 if errors == "raise" and labels_missing:
# -> 4207                     raise KeyError(f"{labels} not found in axis")
#    4208
#    4209             slicer = [slice(None)] * self.ndim
#
# KeyError: '[1 2 3 ... 1481 1482 1483] not found in axis'

# %%
dftest.isna().sum()
# Out:
# customerid                      0
# birthdate                    4524
# bank_account_type            4524
# longitude_gps                4524
# latitude_gps                 4524
# bank_name_clients            4524
# employment_status_clients    4524
# systemloanid                    0
# loannumber                      0
# approveddate                    0
# creationdate                    0
# loanamount                      0
# totaldue                        0
# termdays                        0
# referredby                      0
# closeddate                   1450
# firstduedate                 1450
# firstrepaiddate              1450
# dtype: int64

# %%
#Dropping new loan details i.e loans that have not been paid or scheduled for payment
new_loandrop = dftest[dftest['closeddate'].isna()]
new_loandrop.isna().sum()
# Out:
# customerid                      0
# birthdate                    1065
# bank_account_type            1065
# longitude_gps                1065
# latitude_gps                 1065
# bank_name_clients            1065
# employment_status_clients    1065
# systemloanid                    0
# loannumber                      0
# approveddate                    0
# creationdate                    0
# loanamount                      0
# totaldue                        0
# termdays                        0
# referredby                      0
# closeddate                   1450
# firstduedate                 1450
# firstrepaiddate              1450
# dtype: int64

# %%
to_drop2 = new_loandrop.index

# %%
dftest.drop(to_drop2, inplace = True)

# %%
dftest.isna().sum()
# Out:
# customerid                      0
# birthdate                    2408
# bank_account_type            2408
# longitude_gps                2408
# latitude_gps                 2408
# bank_name_clients            2408
# employment_status_clients    2408
# systemloanid                    0
# loannumber                      0
# approveddate                    0
# creationdate                    0
# loanamount                      0
# totaldue                        0
# termdays                        0
# referredby                      0
# closeddate                      0
# firstduedate                    0
# firstrepaiddate                 0
# dtype: int64

# %% [markdown]
# ### The final data frames are DFTRAIN AND DFTEST

# %% [markdown]
# Looking at both the final training and testing datasets. We want to identify the baasic issues associated with the null values and find a way to solve it

# %%
dftrain.info()

# %%
dftrain.isna().sum()
